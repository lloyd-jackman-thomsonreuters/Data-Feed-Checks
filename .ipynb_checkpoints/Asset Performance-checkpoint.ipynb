# %%
import pandas as pd
import numpy as np
from IPython.display import display
import seaborn as sns
# %matplotlib inline

# %%
gfd1 = pd.read_csv("...\\GFD-1\\AssetPerformance.txt", sep="\t", encoding='cp1252', parse_dates=["EndDate"])
gfd1.head()
# Out:
#    LipperID    EndDate StatCode    ValueLC  BenchmarkValueLC
# 0  65006437 2017-08-17    PCT1D  -0.072060               NaN
# 1  65006437 2017-07-31    PCT1M   3.421730               NaN
# 2  65006437 2017-07-31    PCT2M   5.011070               NaN
# 3  65006437 2017-07-31    PCT3M   3.401962               NaN
# 4  65006437 2017-07-31    PCT6M  18.829120               NaN

# %%
cfg = pd.read_csv("...\\CFG\\AssetPerformance.txt", sep="\t", parse_dates=["EndDate"])
cfg_cols = cfg.columns
cfg.head()
# Out:
#    LipperID    EndDate StatCode   ValueLC  BenchmarkValueLC
# 0  40000041 2016-12-31   PCT1Y0  0.465866               NaN
# 1  40000041 2017-07-31    APF5Y  2.809361               NaN
# 2  40000041 2017-07-31    PCT2M  0.386699               NaN
# 3  40000041 2017-07-31    PCT3M  1.794254               NaN
# 4  40000041 2017-07-31    PCT2Y  6.451705               NaN

# %%
cfg.equals(gfd1)
# Out:
# False

# %%
print("Missing in GFD-1: " + str(len(cfg[~cfg["LipperID"].isin(gfd1["LipperID"])]["LipperID"])))
missing_in_gfd1_df = cfg[~cfg["LipperID"].isin(gfd1["LipperID"])]
missing_in_gfd1 = cfg[~cfg["LipperID"].isin(gfd1["LipperID"])]["LipperID"]


print("Missing in CFG: " + str(len(gfd1[~gfd1["LipperID"].isin(cfg["LipperID"])]["LipperID"])))
missing_in_cfg_df = gfd1[~gfd1["LipperID"].isin(cfg["LipperID"])]
missing_in_cfg = gfd1[~gfd1["LipperID"].isin(cfg["LipperID"])]["LipperID"]

universe_diffs = pd.concat([missing_in_cfg, missing_in_gfd1])
# Out:
# Missing in GFD-1: 1218
# Missing in CFG: 0

# %%
on=["LipperID", "EndDate", "StatCode"]
df = cfg.merge(gfd1, how='outer', on=on, suffixes=("_CFG", "_GFD-1"))
df = df[~df["LipperID"].isin(universe_diffs)]
df = df.fillna("-")
del cfg
del gfd1
df.sample(n=5)
# Out:
#         LipperID              EndDate StatCode ValueLC_CFG  \
# 65922   60056207  2017-07-31 00:00:00    PCT9M   -0.569516
# 682173  68240244  2017-08-17 00:00:00    PCT1D           -
# 209363  65103419  2017-07-31 00:00:00    PCT5Y     65.5309
# 666709  65121741  2017-08-17 00:00:00    PCT1D           -
# 155629  65029248  2012-12-31 00:00:00   PCT1Y4     6.74374
#
#        BenchmarkValueLC_CFG ValueLC_GFD-1 BenchmarkValueLC_GFD-1
# 65922             -0.304401     -0.569511              -0.304413
# 682173                    -      0.394119                      -
# 209363              66.0128       65.5309                66.0128
# 666709                    -      0.230949                      -
# 155629               5.5953       6.74374                 5.5953

# %%
writer = pd.ExcelWriter("Asset Performance Checks.xlsx", engine='xlsxwriter')
df_dict = {}
missing_in_gfd1_df.to_excel(writer,"Additional in new feed", index=False)
missing_in_cfg_df.to_excel(writer,"Missing in new feed", index=False)
for col in cfg_cols[len(on):]:
    print(col+"\n")
    check=[]
    pc_diff=[]
    columns = []
    columns = on + [col+"_CFG", col+"_GFD-1"]
    #print(columns)
    check_df = df.loc[:, columns]
    for n in range(df.shape[0]):
        try:
            diff = float(round((((check_df.iloc[n, -2])/(check_df.iloc[n, -1])-1)*100),2))
            if abs(diff) < 2:
                sig_diff = False
            else:
                sig_diff = True
        except:
            diff = "-"
            sig_diff = True
        pc_diff.append(diff)
        if str(check_df.iloc[n, -2]) == str(check_df.iloc[n, -1]) or (sig_diff == False):
            check.append("Match")
        elif str(check_df.iloc[n, -2]) == "-":
            check.append("Perf not in CFG")
        elif str(check_df.iloc[n, -1]) == "-":
            check.append("Perf not in GFD-1")
        else:
            check.append("Difference")
    check_df["% Diff"] = np.array(pc_diff)
    check_df["Check"] = np.array(check)
    check_df.to_excel(writer,'%s' % col, index=False)
    display(check_df.sample(n=5))
    
writer.save()
# Out:
# ValueLC
#         LipperID              EndDate StatCode ValueLC_CFG ValueLC_GFD-1  \
# 219096  65112931  2017-07-31 00:00:00    PCT1Y     11.7944       11.7945
# 501944  68235382  2017-07-31 00:00:00    PCT3M    0.396614      0.396622
# 214652  65107222  2017-07-31 00:00:00    PCT2M   -0.171135     -0.171143
# 596227  68318571  2017-07-31 00:00:00    PCT3M      1.5268        1.5268
# 138308  65009821  2015-12-31 00:00:00   PCT1Y1       8.159       8.15899
#
#        % Diff  Check
# 219096   -0.0  Match
# 501944   -0.0  Match
# 214652   -0.0  Match
# 596227    0.0  Match
# 138308    0.0  Match
# BenchmarkValueLC
#         LipperID              EndDate StatCode BenchmarkValueLC_CFG  \
# 342152  68105487  2015-12-31 00:00:00   PCT1Y1              10.4236
# 369474  68134190  2017-07-31 00:00:00    PCT2M             0.187276
# 369764  68134471  2017-07-31 00:00:00    PCT4Y              12.4045
# 342996  68106163  2017-07-31 00:00:00    PCT1Y              11.0264
# 540370  68260510  2017-07-31 00:00:00    PCT9M                    -
#
#        BenchmarkValueLC_GFD-1 % Diff  Check
# 342152                10.4236   -0.0  Match
# 369474               0.187279   -0.0  Match
# 369764                12.4045    0.0  Match
# 342996                11.0264    0.0  Match
# 540370                      -      -  Match

# %%
check_df = check_df[check_df["% Diff"] != "-"]
check_df["% Diff"] = check_df["% Diff"].astype(float)
check_piv = pd.pivot_table(check_df, values = ["% Diff"], index=["StatCode"], aggfunc=[len, min, np.mean, max, np.std])
check_piv
